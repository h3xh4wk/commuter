# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
columns=[
    'orig_lat', 
    'orig_lng', 
    'dest_lat', 
    'dest_lng', 
    'weekday', 
    'partofday', 
    'origin', 
    'destination', 
    'distance', 
    'dist_value', 
    'duration', 
    'dur_value',
]

# %%
#data=pd.read_csv('commutes.csv', names=columns) # without names, 1st row was lost in data.columns=columns

# %%
data=pd.read_csv('commutes_1558047627.csv',names=columns)

# %%
print(data.shape)
# Out:
# (92, 12)

# %%
data.head()
# Out:
#     orig_lat  orig_lng   dest_lat   dest_lng  weekday partofday  \
# 0  12.952297  77.57651  12.952297  77.576510        3     night
# 1  12.952297  77.57651  12.929233  77.564420        3     night
# 2  12.952297  77.57651  12.924688  77.617845        3     night
# 3  12.952297  77.57651  12.936233  77.601617        3     night
# 4  12.952297  77.57651  12.941099  77.579828        3     night
#
#                                               origin  \
# 0  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 1  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 2  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 3  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 4  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
#
#                                          destination distance  dist_value  \
# 0  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...      1 m           0
# 1  Indira Nursing Home  13th Cross Rd  Siddanna L...   4.3 km        4298
# ...

# %%
data=data[[
    'orig_lat', 
    'orig_lng', 
    'dest_lat', 
    'dest_lng', 
    'weekday', 
    'partofday', 
    #'origin', 
    #'destination', 
    #'distance', 
    'dist_value', 
    #'duration', 
    'dur_value',
]]

# %%
data.head()
# Out:
#     orig_lat  orig_lng   dest_lat   dest_lng  weekday partofday  dist_value  \
# 0  12.952297  77.57651  12.952297  77.576510        3     night           0
# 1  12.952297  77.57651  12.929233  77.564420        3     night        4298
# 2  12.952297  77.57651  12.924688  77.617845        3     night       17926
# 3  12.952297  77.57651  12.936233  77.601617        3     night        8711
# 4  12.952297  77.57651  12.941099  77.579828        3     night        2051
#
#    dur_value
# 0          0
# 1       1778
# 2       5411
# 3       3714
# 4       1606

# %%
data.head()
# Out:
#     orig_lat  orig_lng   dest_lat   dest_lng  weekday      partofday  \
# 0  12.952297  77.57651  12.952297  77.576510        2  early_morning
# 1  12.952297  77.57651  12.929233  77.564420        2  early_morning
# 2  12.952297  77.57651  12.924688  77.617845        2  early_morning
# 3  12.952297  77.57651  12.936233  77.601617        2  early_morning
# 4  12.952297  77.57651  12.941099  77.579828        2  early_morning
#
#    dist_value  dur_value
# 0           0          0
# 1        3487       1018
# 2        7824       1820
# 3        4899       1223
# 4        3112       1015

# %% [markdown]
# ### Data Collection and Wrangling
#
# 1. Additional features WEEKDAY, TIMEOFDAY
# 2. One combination of origin and destination should also have cordinates - combining cordinates can become and id of a combination - can use finder to get a location's cordinate
