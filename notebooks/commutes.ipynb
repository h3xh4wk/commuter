# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
columns=[
    'orig_lat', 
    'orig_lng', 
    'dest_lat', 
    'dest_lng', 
    'weekday',
    'holiday',
    'partofday', 
    'origin', 
    'destination', 
    'distance', 
    'dist_value', 
    'duration', 
    'dur_value',
    'orig_condition_code',
    'orig_condition_temp',
    'orig_condition_text',
    'orig_wind_chill',
    'orig_wind_direction',
    'orig_wind_speed',
    'orig_atmosphere_humidity',
    'orig_atmosphere_pressure',
    'orig_atmosphere_rising',
    'orig_atmosphere_visibility',
    'dest_condition_code',
    'dest_condition_temp',
    'dest_condition_text',
    'dest_wind_chill',
    'dest_wind_direction',
    'dest_wind_speed',
    'dest_atmosphere_humidity',
    'dest_atmosphere_pressure',
    'dest_atmosphere_rising',
    'dest_atmosphere_visibility'
]

# %%
len(columns)
# Out:
# 33

# %%
data=pd.read_csv('../commutes_1558736659.csv',names=columns)

# %%
print(data.shape)
# Out:
# (98, 33)

# %%
data.head()
# Out:
#     orig_lat  orig_lng   dest_lat   dest_lng  weekday  holiday partofday  \
# 0  12.952297  77.57651  12.952297  77.576510        4        0     night
# 1  12.952297  77.57651  12.929233  77.564420        4        0     night
# 2  12.952297  77.57651  12.921985  77.621046        4        0     night
# 3  12.952297  77.57651  12.935638  77.601471        4        0     night
# 4  12.952297  77.57651  12.936809  77.581277        4        0     night
#
#                                               origin  \
# 0  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 1  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 2  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 3  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
# 4  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...
#
#                                          destination distance  ...  \
# 0  Sajjan Rao Circle  Sajjan Rao Cir  Parvathipur...      1 m  ...
# 1  Indira Nursing Home  13th Cross Rd  Siddanna L...   4.3 km  ...
# ...

# %%
data=data[[
    'orig_lat', 
    'orig_lng', 
    'dest_lat', 
    'dest_lng', 
    'weekday', 
    'holiday',
    'partofday', 
    #'origin', 
    #'destination', 
    #'distance', 
    'dist_value', 
    #'duration', 
    'dur_value',
    'orig_condition_code',
    'orig_condition_temp',
    'orig_condition_text',
    'orig_wind_chill',
    'orig_wind_direction',
    'orig_wind_speed',
    'orig_atmosphere_humidity',
    'orig_atmosphere_pressure',
    'orig_atmosphere_rising',
    'orig_atmosphere_visibility',
    'dest_condition_code',
    'dest_condition_temp',
    'dest_condition_text',
    'dest_wind_chill',
    'dest_wind_direction',
    'dest_wind_speed',
    'dest_atmosphere_humidity',
    'dest_atmosphere_pressure',
    'dest_atmosphere_rising',
    'dest_atmosphere_visibility'
]]

# %%
data.head()
# Out:
#     orig_lat  orig_lng   dest_lat   dest_lng  weekday  holiday partofday  \
# 0  12.952297  77.57651  12.952297  77.576510        4        0     night
# 1  12.952297  77.57651  12.929233  77.564420        4        0     night
# 2  12.952297  77.57651  12.921985  77.621046        4        0     night
# 3  12.952297  77.57651  12.935638  77.601471        4        0     night
# 4  12.952297  77.57651  12.936809  77.581277        4        0     night
#
#    dist_value  dur_value  orig_condition_code  ...  dest_condition_code  \
# 0           0          0                   29  ...                   29
# 1        4298       1778                   29  ...                   29
# 2       13158       5127                   29  ...                   29
# 3        8742       3762                   29  ...                   29
# 4        2052       1606                   29  ...                   29
#
#   dest_condition_temp  dest_condition_text  dest_wind_chill  \
# ...

# %% [markdown]
# ### Data Collection and Wrangling
#
# 1. Additional features WEEKDAY, TIMEOFDAY, WEATHER CONDTIONS
