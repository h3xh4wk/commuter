# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
columns=[
    'place',
    'administrative_unit',
    'population'
]

# %%
data=pd.read_csv('../data/population.csv', names=columns)

# %%
data.head()
# Out:
#                            place administrative_unit  population
# 0     BBMP Municipal Corporation           Karnataka     8443675
# 1  Anekal Town Municipal Council           Karnataka       44260
# 2          Hebbagodi Census Town           Karnataka       34827
# 3           Attibele Census Town           Karnataka       20532
# 4             Jigani Census Town           Karnataka       17036

# %%
data
# Out:
#                              place administrative_unit  population
# 0       BBMP Municipal Corporation           Karnataka     8443675
# 1    Anekal Town Municipal Council           Karnataka       44260
# 2            Hebbagodi Census Town           Karnataka       34827
# 3             Attibele Census Town           Karnataka       20532
# 4               Jigani Census Town           Karnataka       17036
# 5          Bommasandra Census Town           Karnataka       15254
# 6          Dommasandra Census Town           Karnataka       12610
# 7            Sarjapura Census Town           Karnataka       11807
# 8       Maragondahalli Census Town           Karnataka        8824
# 9                      A Medihalli              Anekal         451
# 10               Adigarakallahalli              Anekal        2915
# 11                 Adigondanahalli              Anekal        1354
# 12                            Adur              Anekal         717
# ...
